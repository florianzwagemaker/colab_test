# %% [markdown]
# # HERA bioinformatics training course (test)
#
# In this course the following subjects will come to attention.
# 1. subject1
# 2. subject2
# 3. subject3
#
# Before we start, hover your mouse on the cell below and click the "play" button, this will setup an environment for you to work in. Don't worry, everything you do here has no effect on your own computer! Everything runs in the cloud™
#
# The setup process takes about two minutes.

# %%
# !bash -c "$(curl -sL https://raw.githubusercontent.com/florianzwagemaker/colab_test/main/setup.sh)"

# %% [markdown]
# Has the cell above reported that setup is complete?
# Great! We can now continue and actually start working with some bioinformatics tools

# %% [markdown]
# ## Cleaning reads
#
# This is just a basic example using FastP to clean some reads and write a new fastq file for downstream analysis
#
# click the "play" button in the cell below and badabing badaboom the reads are cleaned

# %%
# %%bash
#
# mkdir -p fastp_output
#
# fastp --thread 1 \
#     -i example_data/sars-cov-2_hong_kong_example.fastq.gz \
#     -A -Q --cut_right \
#     --cut_right_mean_quality 7 \
#     --cut_right_window_size 20 \
#     -l 100 -o  fastp_output/sars-cov-2_hong_kong_example_trimmed.fastq.gz \
#     -h fastp_output/sars-cov-2_hong_kong_example_trimmed.html \
#     -j fastp_output/sars-cov-2_hong_kong_example_trimmed.json
